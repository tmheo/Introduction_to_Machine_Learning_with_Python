# %%
# %matplotlib inline
import sys
print('Python Version: {}'.format(sys.version))

import pandas as pd
print('pandas version: {}'.format(pd.__version__))

import matplotlib
print('matplotlib version: {}'.format(matplotlib.__version__))

import numpy as np
print('numpy version: {}'.format(np.__version__))

import scipy as sp
print('scipy version: {}'.format(sp.__version__))

import IPython
print('ipython version: {}'.format(IPython.__version__))

import sklearn
print('scikit-learn version: {}'.format(sklearn.__version__))

import matplotlib.pyplot as plt

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
matplotlib.rcParams['axes.unicode_minus'] = False

# 한글 폰트 설정
plt.rcParams["font.family"] = 'AppleGothic'

import mglearn

from IPython.display import display
# Out:
# Python Version: 3.5.3 |Anaconda custom (x86_64)| (default, Mar  6 2017, 12:15:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# pandas version: 0.20.3
# matplotlib version: 2.0.2
# numpy version: 1.13.1
# scipy version: 0.19.1
# ipython version: 6.0.0
# scikit-learn version: 0.19.0

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

iris = load_iris()

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=0)
print('훈련 세트의 크기: {}, 테스트 세트의 크기: {}'.format(X_train.shape[0], X_test.shape[0]))

best_score = 0

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        svm = SVC(gamma=gamma, C=C)
        svm.fit(X_train, y_train)
        score = svm.score(X_test, y_test)
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}

print('최고 점수: {:.3f}'.format(best_score))
print('최적 매개변수: {}'.format(best_parameters))
# Out:
# 훈련 세트의 크기: 112, 테스트 세트의 크기: 38
# 최고 점수: 0.974
# 최적 매개변수: {'C': 100, 'gamma': 0.001}

# %%
mglearn.plots.plot_threefold_split()

# %%
from sklearn.svm import SVC

X_trainval, X_test, y_trainval, y_test = train_test_split(iris.data, iris.target, random_state=0)
X_train, X_valid, y_train, y_valid = train_test_split(X_trainval, y_trainval, random_state=1)
print('훈련 세트의 크기: {}, 검증 세트의 크기: {}, 테스트 세트의 크기: {}'.format(X_train.shape[0], X_valid.shape[0], X_test.shape[0]))

best_score = 0

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        svm = SVC(gamma=gamma, C=C)
        svm.fit(X_train, y_train)
        score = svm.score(X_valid, y_valid)
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}

svm = SVC(**best_parameters)
svm.fit(X_trainval, y_trainval)
test_score = svm.score(X_test, y_test)

print('검증 세트에서 최고 점수: {:.3f}'.format(best_score))
print('최적 매개변수: ', best_parameters)
print('최적 매개변수에서 테스트 세트 점수: {:.3f}'.format(test_score))
# Out:
# 훈련 세트의 크기: 84, 검증 세트의 크기: 28, 테스트 세트의 크기: 38
# 검증 세트에서 최고 점수: 0.964
# 최적 매개변수:  {'C': 10, 'gamma': 0.001}
# 최적 매개변수에서 테스트 세트 점수: 0.921

# %%
from sklearn.model_selection import cross_val_score

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        svm = SVC(gamma=gamma, C=C)
        scores = cross_val_score(svm, X_trainval, y_trainval, cv=5)
        score = np.mean(scores)
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}

svm = SVC(**best_parameters)
svm.fit(X_trainval, y_trainval)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
mglearn.plots.plot_cross_val_selection()

# %%
mglearn.plots.plot_grid_search_overview()

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'gamma': [0.001, 0.01, 0.1, 1, 10, 100]
}
print('매개변수 그리드:\n{}'.format(param_grid))
# Out:
# 매개변수 그리드:
# {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

grid_search = GridSearchCV(SVC(), param_grid, cv=5)
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=0)
grid_search.fit(X_train, y_train)

print('테스트 세트 점수: {:.3f}'.format(grid_search.score(X_test, y_test)))
# Out:
# 테스트 세트 점수: 0.974

# %%
print('최적 매개변수: {}'.format(grid_search.best_params_))
print('최상 교차 검증 점수: {:.3f}'.format(grid_search.best_score_))
# Out:
# 최적 매개변수: {'C': 100, 'gamma': 0.01}
# 최상 교차 검증 점수: 0.973

# %%
print('최고 성능 모델:\n{}'.format(grid_search.best_estimator_))
# Out:
# 최고 성능 모델:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
import pandas as pd

results = pd.DataFrame(grid_search.cv_results_)
display(results.head())
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0       0.000808         0.000303         0.366071          0.366079   0.001
# 1       0.000625         0.000266         0.366071          0.366079   0.001
# 2       0.000663         0.000310         0.366071          0.366079   0.001
# 3       0.000622         0.000249         0.366071          0.366079   0.001
# 4       0.000782         0.000313         0.366071          0.366079   0.001
#
#   param_gamma                        params  rank_test_score  \
# 0       0.001  {'C': 0.001, 'gamma': 0.001}               22
# 1        0.01   {'C': 0.001, 'gamma': 0.01}               22
# 2         0.1    {'C': 0.001, 'gamma': 0.1}               22
# 3           1      {'C': 0.001, 'gamma': 1}               22
# 4          10     {'C': 0.001, 'gamma': 10}               22
#
#    split0_test_score  split0_train_score       ...         split2_test_score  \
# 0              0.375            0.363636       ...                  0.363636
# 1              0.375            0.363636       ...                  0.363636
# 2              0.375            0.363636       ...                  0.363636
# 3              0.375            0.363636       ...                  0.363636
# 4              0.375            0.363636       ...                  0.363636
#
#    split2_train_score  split3_test_score  split3_train_score  \
# 0            0.366667           0.363636            0.366667
# 1            0.366667           0.363636            0.366667
# 2            0.366667           0.363636            0.366667
# 3            0.366667           0.363636            0.366667
# 4            0.366667           0.363636            0.366667
#
#    split4_test_score  split4_train_score  std_fit_time  std_score_time  \
# 0           0.380952            0.362637      0.000232        0.000072
# 1           0.380952            0.362637      0.000048        0.000034
# 2           0.380952            0.362637      0.000048        0.000063
# 3           0.380952            0.362637      0.000025        0.000005
# 4           0.380952            0.362637      0.000060        0.000023
#
#    std_test_score  std_train_score
# 0        0.011371         0.002852
# 1        0.011371         0.002852
# 2        0.011371         0.002852
# 3        0.011371         0.002852
# 4        0.011371         0.002852
#
# [5 rows x 22 columns]

# %%
scores = np.array(results.mean_test_score).reshape(6, 6)

mglearn.tools.heatmap(scores, xlabel='gamma', xticklabels=param_grid['gamma'], ylabel='C', yticklabels=param_grid['C'], cmap='viridis')

# %%
fig, axes = plt.subplots(1, 3, figsize=(13, 5))
param_grid_linear = {'C': np.linspace(1, 2, 6),
                    'gamma': np.linspace(1, 2, 6)}
param_grid_one_log = {'C': np.linspace(1, 2, 6),
                     'gamma': np.logspace(-3, 2, 6)}
param_grid_range = {'C': np.logspace(-3, 2, 6),
                   'gamma': np.logspace(-7, -2, 6)}
for param_grid, ax in zip([param_grid_linear, param_grid_one_log, param_grid_range], axes):
    grid_search = GridSearchCV(SVC(), param_grid, cv=5)
    grid_search.fit(X_train, y_train)
    scores = grid_search.cv_results_['mean_test_score'].reshape(6, 6)
    
    scores_image = mglearn.tools.heatmap(scores, xlabel='gamma', ylabel='C',
                                         xticklabels=param_grid['gamma'], yticklabels=param_grid['C'], cmap='viridis', ax=ax)
plt.colorbar(scores_image, ax=axes.tolist())

# %%
param_grid = [
    {'kernel': ['rbf'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'gamma': [0.001, 0.01, 0.1, 1, 10, 100]},
    {'kernel': ['linear'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100]}
]
print('그리드 목록:\n{}'.format(param_grid))
# Out:
# 그리드 목록:
# [{'C': [0.001, 0.01, 0.1, 1, 10, 100], 'kernel': ['rbf'], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}, {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'kernel': ['linear']}]

# %%
grid_search = GridSearchCV(SVC(), param_grid, cv=5)
grid_search.fit(X_train, y_train)
print('최적 매개변수: {}'.format(grid_search.best_params_))
print('최고 교차 검증 점수: {:.3f}'.format(grid_search.best_score_))
# Out:
# 최적 매개변수: {'C': 100, 'kernel': 'rbf', 'gamma': 0.01}
# 최고 교차 검증 점수: 0.973

# %%
results = pd.DataFrame(grid_search.cv_results_)
display(results.T)
# Out:
#                                                                0   \
# mean_fit_time                                         0.000647545
# mean_score_time                                       0.000277185
# mean_test_score                                          0.366071
# mean_train_score                                         0.366079
# param_C                                                     0.001
# param_gamma                                                 0.001
# param_kernel                                                  rbf
# params              {'C': 0.001, 'kernel': 'rbf', 'gamma': 0.001}
# rank_test_score                                                27
# split0_test_score                                           0.375
# split0_train_score                                       0.363636
# split1_test_score                                        0.347826
# split1_train_score                                       0.370787
# split2_test_score                                        0.363636
# split2_train_score                                       0.366667
# split3_test_score                                        0.363636
# split3_train_score                                       0.366667
# split4_test_score                                        0.380952
# split4_train_score                                       0.362637
# std_fit_time                                          9.03179e-05
# std_score_time                                        5.27362e-05
# std_test_score                                          0.0113708
# std_train_score                                        0.00285176
#
#                                                               1   \
# mean_fit_time                                        0.000651646
# mean_score_time                                      0.000290966
# mean_test_score                                         0.366071
# mean_train_score                                        0.366079
# param_C                                                    0.001
# param_gamma                                                 0.01
# param_kernel                                                 rbf
# params              {'C': 0.001, 'kernel': 'rbf', 'gamma': 0.01}
# rank_test_score                                               27
# split0_test_score                                          0.375
# split0_train_score                                      0.363636
# split1_test_score                                       0.347826
# split1_train_score                                      0.370787
# split2_test_score                                       0.363636
# split2_train_score                                      0.366667
# split3_test_score                                       0.363636
# split3_train_score                                      0.366667
# split4_test_score                                       0.380952
# split4_train_score                                      0.362637
# std_fit_time                                         9.78092e-05
# std_score_time                                       6.04101e-05
# std_test_score                                         0.0113708
# std_train_score                                       0.00285176
#
#                                                              2   \
# mean_fit_time                                       0.000597143
# mean_score_time                                      0.00025382
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                   0.001
# param_gamma                                                 0.1
# param_kernel                                                rbf
# params              {'C': 0.001, 'kernel': 'rbf', 'gamma': 0.1}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        1.82278e-05
# std_score_time                                      1.34216e-05
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                            3   \
# mean_fit_time                                     0.000601435
# mean_score_time                                   0.000240564
# mean_test_score                                      0.366071
# mean_train_score                                     0.366079
# param_C                                                 0.001
# param_gamma                                                 1
# param_kernel                                              rbf
# params              {'C': 0.001, 'kernel': 'rbf', 'gamma': 1}
# rank_test_score                                            27
# split0_test_score                                       0.375
# split0_train_score                                   0.363636
# split1_test_score                                    0.347826
# split1_train_score                                   0.370787
# split2_test_score                                    0.363636
# split2_train_score                                   0.366667
# split3_test_score                                    0.363636
# split3_train_score                                   0.366667
# split4_test_score                                    0.380952
# split4_train_score                                   0.362637
# std_fit_time                                      3.57328e-05
# std_score_time                                    1.25291e-05
# std_test_score                                      0.0113708
# std_train_score                                    0.00285176
#
#                                                             4   \
# mean_fit_time                                      0.000862789
# mean_score_time                                     0.00036397
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                  0.001
# param_gamma                                                 10
# param_kernel                                               rbf
# params              {'C': 0.001, 'kernel': 'rbf', 'gamma': 10}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                       0.000129213
# std_score_time                                     9.30834e-05
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                              5   \
# mean_fit_time                                       0.000668573
# mean_score_time                                     0.000257826
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                   0.001
# param_gamma                                                 100
# param_kernel                                                rbf
# params              {'C': 0.001, 'kernel': 'rbf', 'gamma': 100}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        7.09593e-05
# std_score_time                                      1.47362e-05
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                               6   \
# mean_fit_time                                        0.000586653
# mean_score_time                                      0.000239754
# mean_test_score                                         0.366071
# mean_train_score                                        0.366079
# param_C                                                     0.01
# param_gamma                                                0.001
# param_kernel                                                 rbf
# params              {'C': 0.01, 'kernel': 'rbf', 'gamma': 0.001}
# rank_test_score                                               27
# split0_test_score                                          0.375
# split0_train_score                                      0.363636
# split1_test_score                                       0.347826
# split1_train_score                                      0.370787
# split2_test_score                                       0.363636
# split2_train_score                                      0.366667
# split3_test_score                                       0.363636
# split3_train_score                                      0.366667
# split4_test_score                                       0.380952
# split4_train_score                                      0.362637
# std_fit_time                                         2.12482e-05
# std_score_time                                       7.17573e-06
# std_test_score                                         0.0113708
# std_train_score                                       0.00285176
#
#                                                              7   \
# mean_fit_time                                       0.000576162
# mean_score_time                                     0.000271368
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                    0.01
# param_gamma                                                0.01
# param_kernel                                                rbf
# params              {'C': 0.01, 'kernel': 'rbf', 'gamma': 0.01}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        2.08256e-05
# std_score_time                                      7.39825e-05
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                             8   \
# mean_fit_time                                      0.000601816
# mean_score_time                                     0.00026536
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                   0.01
# param_gamma                                                0.1
# param_kernel                                               rbf
# params              {'C': 0.01, 'kernel': 'rbf', 'gamma': 0.1}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                       7.14978e-05
# std_score_time                                     4.04194e-05
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                           9   \
# mean_fit_time                                    0.000729036
# mean_score_time                                  0.000336123
# mean_test_score                                     0.366071
# mean_train_score                                    0.366079
# param_C                                                 0.01
# param_gamma                                                1
# param_kernel                                             rbf
# params              {'C': 0.01, 'kernel': 'rbf', 'gamma': 1}
# rank_test_score                                           27
# split0_test_score                                      0.375
# split0_train_score                                  0.363636
# split1_test_score                                   0.347826
# split1_train_score                                  0.370787
# split2_test_score                                   0.363636
# split2_train_score                                  0.366667
# split3_test_score                                   0.363636
# split3_train_score                                  0.366667
# split4_test_score                                   0.380952
# split4_train_score                                  0.362637
# std_fit_time                                     5.18932e-05
# std_score_time                                   8.56868e-05
# std_test_score                                     0.0113708
# std_train_score                                   0.00285176
#
#                                  ...                \
# mean_fit_time                    ...
# mean_score_time                  ...
# mean_test_score                  ...
# mean_train_score                 ...
# param_C                          ...
# param_gamma                      ...
# param_kernel                     ...
# params                           ...
# rank_test_score                  ...
# split0_test_score                ...
# split0_train_score               ...
# split1_test_score                ...
# split1_train_score               ...
# split2_test_score                ...
# split2_train_score               ...
# split3_test_score                ...
# split3_train_score               ...
# split4_test_score                ...
# split4_train_score               ...
# std_fit_time                     ...
# std_score_time                   ...
# std_test_score                   ...
# std_train_score                  ...
#
#                                                            32  \
# mean_fit_time                                     0.000370407
# mean_score_time                                   0.000200224
# mean_test_score                                      0.955357
# mean_train_score                                     0.988788
# param_C                                                   100
# param_gamma                                               0.1
# param_kernel                                              rbf
# params              {'C': 100, 'kernel': 'rbf', 'gamma': 0.1}
# rank_test_score                                             9
# split0_test_score                                    0.958333
# split0_train_score                                   0.988636
# split1_test_score                                           1
# split1_train_score                                   0.977528
# split2_test_score                                           1
# split2_train_score                                   0.977778
# split3_test_score                                    0.863636
# split3_train_score                                          1
# split4_test_score                                    0.952381
# split4_train_score                                          1
# std_fit_time                                      6.42273e-05
# std_score_time                                    1.73259e-05
# std_test_score                                      0.0495662
# std_train_score                                    0.00999451
#
#                                                          33  \
# mean_fit_time                                   0.000525188
# mean_score_time                                 0.000263357
# mean_test_score                                    0.946429
# mean_train_score                                          1
# param_C                                                 100
# param_gamma                                               1
# param_kernel                                            rbf
# params              {'C': 100, 'kernel': 'rbf', 'gamma': 1}
# rank_test_score                                          11
# split0_test_score                                  0.916667
# split0_train_score                                        1
# split1_test_score                                         1
# split1_train_score                                        1
# split2_test_score                                         1
# split2_train_score                                        1
# split3_test_score                                  0.863636
# split3_train_score                                        1
# split4_test_score                                  0.952381
# split4_train_score                                        1
# std_fit_time                                    0.000169775
# std_score_time                                  7.54287e-05
# std_test_score                                    0.0519227
# std_train_score                                           0
#
#                                                           34  \
# mean_fit_time                                    0.000985336
# mean_score_time                                  0.000277853
# mean_test_score                                     0.919643
# mean_train_score                                           1
# param_C                                                  100
# param_gamma                                               10
# param_kernel                                             rbf
# params              {'C': 100, 'kernel': 'rbf', 'gamma': 10}
# rank_test_score                                           17
# split0_test_score                                      0.875
# split0_train_score                                         1
# split1_test_score                                   0.956522
# split1_train_score                                         1
# split2_test_score                                          1
# split2_train_score                                         1
# split3_test_score                                   0.818182
# split3_train_score                                         1
# split4_test_score                                   0.952381
# split4_train_score                                         1
# std_fit_time                                     8.75123e-05
# std_score_time                                   3.94859e-05
# std_test_score                                     0.0647906
# std_train_score                                            0
#
#                                                            35  \
# mean_fit_time                                     0.000816774
# mean_score_time                                   0.000233889
# mean_test_score                                        0.5625
# mean_train_score                                            1
# param_C                                                   100
# param_gamma                                               100
# param_kernel                                              rbf
# params              {'C': 100, 'kernel': 'rbf', 'gamma': 100}
# rank_test_score                                            24
# split0_test_score                                    0.541667
# split0_train_score                                          1
# split1_test_score                                    0.478261
# split1_train_score                                          1
# split2_test_score                                    0.590909
# split2_train_score                                          1
# split3_test_score                                    0.590909
# split3_train_score                                          1
# split4_test_score                                    0.619048
# split4_train_score                                          1
# std_fit_time                                       3.1644e-05
# std_score_time                                    5.12461e-06
# std_test_score                                      0.0496678
# std_train_score                                             0
#
#                                                   36  \
# mean_fit_time                             0.00043602
# mean_score_time                          0.000208998
# mean_test_score                             0.366071
# mean_train_score                            0.366079
# param_C                                        0.001
# param_gamma                                      NaN
# param_kernel                                  linear
# params              {'C': 0.001, 'kernel': 'linear'}
# rank_test_score                                   27
# split0_test_score                              0.375
# split0_train_score                          0.363636
# split1_test_score                           0.347826
# split1_train_score                          0.370787
# split2_test_score                           0.363636
# split2_train_score                          0.366667
# split3_test_score                           0.363636
# split3_train_score                          0.366667
# split4_test_score                           0.380952
# split4_train_score                          0.362637
# std_fit_time                             1.95843e-05
# std_score_time                           1.13409e-05
# std_test_score                             0.0113708
# std_train_score                           0.00285176
#
#                                                  37  \
# mean_fit_time                           0.000399446
# mean_score_time                         0.000211334
# mean_test_score                            0.848214
# mean_train_score                           0.855069
# param_C                                        0.01
# param_gamma                                     NaN
# param_kernel                                 linear
# params              {'C': 0.01, 'kernel': 'linear'}
# rank_test_score                                  21
# split0_test_score                          0.916667
# split0_train_score                         0.886364
# split1_test_score                          0.826087
# split1_train_score                          0.88764
# split2_test_score                          0.818182
# split2_train_score                         0.866667
# split3_test_score                          0.772727
# split3_train_score                         0.755556
# split4_test_score                          0.904762
# split4_train_score                         0.879121
# std_fit_time                            3.17824e-05
# std_score_time                          2.03345e-05
# std_test_score                            0.0547783
# std_train_score                           0.0503114
#
#                                                 38  \
# mean_fit_time                          0.000332832
# mean_score_time                        0.000218821
# mean_test_score                           0.946429
# mean_train_score                          0.966538
# param_C                                        0.1
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 0.1, 'kernel': 'linear'}
# rank_test_score                                 11
# split0_test_score                         0.958333
# split0_train_score                        0.965909
# split1_test_score                         0.913043
# split1_train_score                        0.977528
# split2_test_score                                1
# split2_train_score                        0.944444
# split3_test_score                         0.909091
# split3_train_score                        0.977778
# split4_test_score                         0.952381
# split4_train_score                        0.967033
# std_fit_time                           1.25699e-05
# std_score_time                         3.39993e-05
# std_test_score                           0.0332185
# std_train_score                          0.0121316
#
#                                               39  \
# mean_fit_time                        0.000315619
# mean_score_time                      0.000192595
# mean_test_score                         0.973214
# mean_train_score                        0.984368
# param_C                                        1
# param_gamma                                  NaN
# param_kernel                              linear
# params              {'C': 1, 'kernel': 'linear'}
# rank_test_score                                1
# split0_test_score                              1
# split0_train_score                      0.988636
# split1_test_score                       0.956522
# split1_train_score                      0.977528
# split2_test_score                              1
# split2_train_score                      0.977778
# split3_test_score                       0.954545
# split3_train_score                      0.988889
# split4_test_score                       0.952381
# split4_train_score                      0.989011
# std_fit_time                         1.00752e-05
# std_score_time                       2.45652e-06
# std_test_score                         0.0223995
# std_train_score                       0.00548507
#
#                                                40  \
# mean_fit_time                         0.000318384
# mean_score_time                        0.00019002
# mean_test_score                          0.964286
# mean_train_score                         0.988813
# param_C                                        10
# param_gamma                                   NaN
# param_kernel                               linear
# params              {'C': 10, 'kernel': 'linear'}
# rank_test_score                                 3
# split0_test_score                        0.958333
# split0_train_score                       0.988636
# split1_test_score                               1
# split1_train_score                       0.988764
# split2_test_score                               1
# split2_train_score                       0.977778
# split3_test_score                        0.909091
# split3_train_score                       0.988889
# split4_test_score                        0.952381
# split4_train_score                              1
# std_fit_time                            1.369e-05
# std_score_time                        2.22126e-06
# std_test_score                          0.0338387
# std_train_score                        0.00702801
#
#                                                 41
# mean_fit_time                           0.00050416
# mean_score_time                         0.00027566
# mean_test_score                           0.964286
# mean_train_score                          0.993258
# param_C                                        100
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 100, 'kernel': 'linear'}
# rank_test_score                                  3
# split0_test_score                         0.958333
# split0_train_score                        0.988636
# split1_test_score                                1
# split1_train_score                        0.988764
# split2_test_score                                1
# split2_train_score                        0.988889
# split3_test_score                         0.909091
# split3_train_score                               1
# split4_test_score                         0.952381
# split4_train_score                               1
# std_fit_time                           0.000119168
# std_score_time                         6.03913e-05
# std_test_score                           0.0338387
# std_train_score                         0.00550551
#
# [23 rows x 42 columns]

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
             'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
scores = cross_val_score(GridSearchCV(SVC(), param_grid, cv=5), iris.data, iris.target, cv=5)
print('교차 검증 점수: ', scores)
print('교차 검증 평균 점수: ', scores.mean())
# Out:
# 교차 검증 점수:  [ 0.96666667  1.          0.96666667  0.96666667  1.        ]
# 교차 검증 평균 점수:  0.98

# %%
def nested_cv(X, y, inner_cv, outer_cv, Classifier, parameter_grid):
    outer_scores = []
    for training_samples, test_samples in outer_cv.split(X, y):
        best_parms = {}
        best_score = -np.inf
        for parameters in parameter_grid:
            cv_scores = []
            for inner_train, inner_test in inner_cv.split(X[training_samples], y[training_samples]):
                clf = Classifier(**parameters)
                clf.fit(X[inner_train], y[inner_train])
                score = clf.score(X[inner_test], y[inner_test])
                cv_scores.append(score)
            mean_score = np.mean(cv_scores)
            if mean_score > best_score:
                best_score = mean_score
                best_params = parameters
        clf = Classifier(**best_params)
        clf.fit(X[training_samples], y[training_samples])
        outer_scores.append(clf.score(X[test_samples], y[test_samples]))
    return np.array(outer_scores)

# %%
from sklearn.model_selection import ParameterGrid, StratifiedKFold

scores = nested_cv(iris.data, iris.target, StratifiedKFold(5), StratifiedKFold(5),
                  SVC, ParameterGrid(param_grid))
print('교차 검증 점수: {}'.format(scores))
# Out:
# 교차 검증 점수: [ 0.96666667  1.          0.96666667  0.96666667  1.        ]
